# %% [markdown]
# # Setting up a notebook:

# %% [markdown]
# ##     Goals:
#
#         1. download data from a website,
#         2. display and graph the data.

# %%
import urllib2
import urllib

# Specify the url
url = 'http://gyre.umeoce.maine.edu/data/gomoos/buoy/php/view_csv_file.php?ncfile=/data/gomoos/buoy/archive/PR106/realtime/PR106.sbe37.realtime.1m.nc'

# This packages the request (it doesn't make it) 
request = urllib2.Request(url)

# Sends the request and catches the response
response = urllib2.urlopen(request)

# Extracts the response
html = response.read()

# Print it out
print html 

# Render our plots inline
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

broken_df = pd.read_csv('http://gyre.umeoce.maine.edu/data/gomoos/buoy/php/view_csv_file.php?ncfile=/data/gomoos/buoy/archive/PR106/realtime/PR106.sbe37.realtime.1m.nc')
fixed_df = pd.read_csv('http://gyre.umeoce.maine.edu/data/gomoos/buoy/php/view_csv_file.php?ncfile=/data/gomoos/buoy/archive/PR106/realtime/PR106.sbe37.realtime.1m.nc', sep=';', encoding='latin1', parse_dates=['Date'], index_col='Date')
fixed_df.plot(figsize=(15, 10))
# Out:
# Time[GMT],salinity[psu](1m),sigma_t[kg/m^3](1m),conductivity[msiemens/cm](1m),temperature[C](1m)
# 2013-05-24 13:00,36.194,23.443,57.425,27.55
# 2013-05-24 14:00,36.203,23.439,57.474,27.58
# 2013-05-24 15:00,36.169,23.380,57.537,27.68
# 2013-05-24 16:00,36.171,23.362,57.602,27.74
# 2013-05-24 17:00,36.174,23.356,57.638,27.77
# 2013-05-24 18:00,36.157,23.317,57.699,27.85
# 2013-05-24 19:00,36.174,23.335,57.709,27.83
# 2013-05-24 20:00,36.190,23.346,57.732,27.83
# 2013-05-24 21:00,36.191,23.348,57.731,27.83
# 2013-05-24 22:00,36.203,23.370,57.704,27.79
# 2013-05-24 23:00,36.230,23.396,57.724,27.77
# 2013-05-25 00:00,36.226,23.391,57.722,27.78
# 2013-05-25 01:00,36.244,23.412,57.724,27.76
# 2013-05-25 02:00,36.254,23.420,57.739,27.76
# 2013-05-25 03:00,36.256,23.422,57.738,27.75
# 2013-05-25 04:00,36.259,23.432,57.720,27.73
# 2013-05-25 05:00,36.260,23.433,57.717,27.73
# 2013-05-25 06:00,36.272,23.454,57.693,27.69
# 2013-05-25 07:00,36.320,23.491,57.760,27.69
# ...

# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library: 
##from (library) import (specific library function)
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number

# Enable inline plotting
# %matplotlib inline

Location = r"http://gyre.umeoce.maine.edu/data/gomoos/buoy/php/view_csv_file.php?ncfile=/data/gomoos/buoy/archive/PR106/realtime/PR106.sbe37.realtime.1m.nc"
df = pd.read_csv(Location, parse_dates=['Time[GMT]'])
df
df.plot(title = "Caricoos Ponce Buoy")

# %%
import urllib2
import urllib

# Specify the url
url = 'http://gyre.umeoce.maine.edu/data/gomoos/buoy/php/view_csv_file.php?ncfile=/data/gomoos/buoy/archive/PR106/realtime/PR106.sbe37.realtime.1m.nc'

# This packages the request (it doesn't make it) 
request = urllib2.Request(url)

# Sends the request and catches the response
response = urllib2.urlopen(request)

# Extracts the response
html = response.read()

# Print it out
###print html 

# Render our plots inline
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

broken_df = pd.read_csv('http://gyre.umeoce.maine.edu/data/gomoos/buoy/php/view_csv_file.php?ncfile=/data/gomoos/buoy/archive/PR106/realtime/PR106.sbe37.realtime.1m.nc')
fixed_df = pd.read_csv('http://gyre.umeoce.maine.edu/data/gomoos/buoy/php/view_csv_file.php?ncfile=/data/gomoos/buoy/archive/PR106/realtime/PR106.sbe37.realtime.1m.nc', sep=';', encoding='latin1', parse_dates=['Date'], index_col='Date')
fixed_df.plot(figsize=(15, 10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-a351aaed0536> in <module>()
#      27
#      28 broken_df = pd.read_csv('http://gyre.umeoce.maine.edu/data/gomoos/buoy/php/view_csv_file.php?ncfile=/data/gomoos/buoy/archive/PR106/realtime/PR106.sbe37.realtime.1m.nc')
# ---> 29 fixed_df = pd.read_csv('http://gyre.umeoce.maine.edu/data/gomoos/buoy/php/view_csv_file.php?ncfile=/data/gomoos/buoy/archive/PR106/realtime/PR106.sbe37.realtime.1m.nc', sep=';', encoding='latin1', parse_dates=['Date'], index_col='Date')
#      30 fixed_df.plot(figsize=(15, 10))
#
# ...

# %%
import urllib2
import urllib

url = 'http://gyre.umeoce.maine.edu/data/gomoos/buoy/php/view_csv_file.php?ncfile=/data/gomoos/buoy/archive/PR106/realtime/PR106.sbe37.realtime.1m.nc'

#package request
request = urllib2.Request(url)

#send request
response = urllib2.urlopen(request)

#extract response
html = response.read()

#print
###print html

#plot inline
# %matplotlib inline

#pandas analyzes data
import pandas as pd
import matplotlib.pyplot as plt

Location = r"http://gyre.umeoce.maine.edu/data/gomoos/buoy/php/view_csv_file.php?ncfile=/data/gomoos/buoy/archive/PR106/realtime/PR106.sbe37.realtime.1m.nc"
#set the first column as index and specify that it is a date
##otherwise the x axis begins numbering 0 through ...
df = pd.read_csv(Location, index_col=0, parse_dates=[0])
df
df.plot(title = "Caricoos PonceBuoy")

# %%
import urllib2
import urllib

url = 'http://gyre.umeoce.maine.edu/data/gomoos/buoy/php/view_csv_file.php?ncfile=/data/gomoos/buoy/archive/PR106/realtime/PR106.sbe37.realtime.1m.nc'

#package request
request = urllib2.Request(url)

#send request
response = urllib2.urlopen(request)

#extract response
html = response.read()

#print
###print html

#plot inline
# %matplotlib inline

#pandas analyzes data
import pandas as pd
import matplotlib.pyplot as plt

#this is not needed??? 
###headers = ['Date', 'salinity', 'sigma_t', 'conductivity', 'temperature']

#set the first column as index and specify that it is a date
##otherwise the x axis begins numbering 0 through ...
###df = pd.read_csv(url, index_col=0, parse_dates=[0])
###df

#Use a number to indicate the column to graph. Begin with '0' but the first column which is the date does not count.
df[[0,1]].plot(title = "Caricoos PonceBuoy")

# %%
df[[0, 1]].describe()
# Out:
#        salinity[psu](1m)  sigma_t[kg/m^3](1m)
# count        8134.000000          8134.000000
# mean           35.241569            22.580833
# std             0.665327             0.751751
# min            30.086000            18.767000
# 25%            34.727000            21.934000
# 50%            35.133500            22.598000
# 75%            35.958000            23.245000
# max            36.433000            23.745000

# %%
git
